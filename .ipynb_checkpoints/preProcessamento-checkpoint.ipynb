# %%
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup
import requests as r
import calendar
import datetime
import MySQLdb

# %% [markdown]
# ## Functions

# %%
##regex to find news on HTML
pattern_news = re.compile('N[1-9]')
##then crawler have to use more than one strategy to get data
pattern_title = re.compile('[1-9] -')

d = {
    'janeiro': '01',
    'fevereiro': '02',
    'março': '03',
    'abril': '04',
    'maio': '05',
    'junho': '06',
    'julho': '07',
    'agosto': '08',
    'setembro': '09',
    'outubro': '10',
    'novembro': '11',
    'dezembro': '12'
}



#fill nan titles
def fill_nan_noticia_title(df):
    for i in range(len(df['noticia-titulo'])):
        if (pd.isna(df['noticia-titulo'][i]) and re.search(pattern_title, df['noticia-strong'][i].__str__())):
            df['noticia-titulo'][i] = df['noticia-strong'][i]

## Split title
def split_title(df):
    for k, v in enumerate(df['noticia-titulo']):
        df['noticia-titulo'][k] = re.split(r'[2-9] -|[2-9]\)', v.__str__() )

def parse_date(df):
    number_list = []
    date_list = []
    
    for k,v in enumerate(df['boletim-titulo']):
        number, date = re.split(r'[\-\|]', v)
        number = re.sub("\D", '', number)
        number_list.append(number)
        try:
            day, month, year = date.split(' de ')
            month = d[month]
        except:
            print(k)
            day, month, year = date.split('/')
        
        day = day.replace('º','')
        date_list.append('{}-{}-{}'.format(year,month,day).replace(' ',''))
        
    df['numero'] = number_list
    df['data'] = date_list


## insert boletim on db
def insert_boletim(df):
    con = MySQLdb.connect('localhost', 'juaumpc', 'root')
    con.select_db('doug_db')
    cursor = con.cursor()
    for k, v in enumerate(df['news']):
        sqlcommand = 'INSERT INTO  doug_server_app_boletim (data, numero) VALUES ("{}", {});'.format(df['data'][k], int(df['numero'][k]))
        cursor.execute(sqlcommand)
    con.commit()
    con.close()

# %% [markdown]
# ## Reading CSV File
#
# The csv file contains a amount of html from pages crawled by scrapy

# %%
df = pd.read_csv('file.csv', encoding='utf-8')

# %%
df['noticia-titulo'][40]
# Out:
# '<strong>1 - Progp esclarece sobre abono de ponto no recesso de final de ano</strong>,<strong>2 - Assin retifica edital de seleção de bolsista do programa Flagship</strong>,<strong>3 - Nota de falecimento</strong>,<strong>Pós-Graduação em Engenharia Química\xa0 da UFSJ/CAP convida para exame de qualificação</strong>,<strong>5 - UFSJ convida para Café com Você 2018</strong>'

# %% [markdown]
# #### HTML clear
#
# Iterate all html title's new removing all DOM, controller characters and punctuation

# %%
for k,v in enumerate(df['noticia-titulo']):
    if(not(pd.isna(v))):
        new = BeautifulSoup(v.__str__(), 'html.parser').text
        new = re.sub('\xa0',' ', new )
        new = re.sub('\n|\t|\r', '', new)
        new = re.sub(',', '', new)
        df['noticia-titulo'][k] = new

df.dropna(subset=['noticia-titulo'], inplace=True)
df.reset_index(drop= True, inplace= True)

# %% [markdown]
# ## Number of missing values from df new's title

# %%
pd.isna(df['noticia-titulo']).sum()
# Out:
# 0

# %% [markdown]
# ## Parsing of titles and dates
# Extracting dates and boletim number

# %%
split_title(df)
parse_date(df)
# Out:
# 16

# %% [markdown]
# ## Cleaning Html on News body
# Removing all DOM and controller characters from new's body

# %%
for k, v in enumerate(df.news):
    df.news[k]= BeautifulSoup(v.__str__(), 'html.parser').text

# %%
for k, v in enumerate(df.news):
    df.news[k] = re.sub('\n|\t|\r', '',v)
    df.news[k] = re.sub('\xa0', ' ', df.news[k])

# %% [markdown]
# ## Spliting News according with titles
# When news are extracted from UFSJ official site, we need to split news in order to make every independent from anothers, in that way we turn better chatbot's answer to user

# %%
news = []
for index, new in enumerate(df.news):
    aux = []
    corte = new
    titulos = df['noticia-titulo'][index]
    titulos.reverse()
    titulos = list(filter(None, titulos))

    for k, v in enumerate(titulos):
        corte = corte.split(v)
        
        try:
            aux.append(corte[1])
            
        except:
            aux.append(corte[0])
            
        corte = corte[0]
        
    titulos.reverse()
    df['noticia-titulo'][index] = titulos
    aux.reverse()
    df.news[index] = aux
print('number of boletins extracted from site: {}'.format(len(df.news)))
# Out:
# number of boletins extracted from site: 83

# %% [markdown]
# ## Resulted DataFrame

# %%
df
# Out:
#                              boletim-titulo  \
# 0       Boletim nº 9 - 9 de outubro de 2018
# 1     Boletim nº 12 - 15 de outubro de 2018
# 2     Boletim nº 10 - 10 de outubro de 2018
# 3     Boletim nº 11 - 11 de outubro de 2018
# 4     Boletim nº 14 - 17 de outubro de 2018
# 5     Boletim nº 16 - 19 de outubro de 2018
# 6     Boletim nº 15 | 18 de outubro de 2018
# 7     Boletim nº 13 - 16 de outubro de 2018
# 8     Boletim nº 19 - 24 de outubro de 2018
# 9     Boletim nº 17 - 22 de outubro de 2018
# 10    Boletim nº 24 - 5 de novembro de 2018
# 11    Boletim nº 21 - 26 de outubro de 2018
# 12    Boletim nº 20 - 25 de outubro de 2018
# 13    Boletim nº 22 - 31 de outubro de 2018
# 14   Boletim nº 23 - 1º de novembro de 2018
# 15    Boletim nº 25 - 6 de novembro de 2018
# 16        Boletim Interno nº18 - 23/10/2018
# 17    Boletim nº 26 - 7 de novembro de 2018
# 18    Boletim nº 27 - 8 de novembro de 2018
# 19   Boletim nº 32 - 21 de novembro de 2018
# 20   Boletim nº 31 - 20 de novembro de 2018
# 21    Boletim nº 28 - 9 de novembro de 2018
# 22   Boletim nº 29 - 13 de novembro de 2018
# 23   Boletim nº 39 - 30 de novembro de 2018
# 24   Boletim nº 35 - 26 de novembro de 2018
# 25    Boletim nº 40 - 3 de dezembro de 2018
# 26   Boletim nº 38 - 29 de novembro de 2018
# 27    Boletim nº 41 - 4 de dezembro de 2018
# 28   Boletim nº 37 - 28 de novembro de 2018
# 29   Boletim nº 30 - 19 de novembro de 2018
# ..                                      ...
# 53    Boletim nº 66 - 28 de janeiro de 2019
# 54    Boletim nº 60 - 15 de janeiro de 2018
# 55    Boletim nº 61 - 16 de janeiro de 2019
# 25  [1 - Proex lança edital para bolsistas de incl...
# 26  [1 - 1º Workshop do Profmat UFSJ ocorre no dia...
# 27  [1 - Netec seleciona dois bolsistas para atuar...
# 28  [1 - Eleições para CPPD e Congregação ocorrem ...
# 29  [1 - Deceb/Sete Lagoas seleciona servidor para...
# ..                                                ...
# 53  [1 - Proae lança edital do Processo de Avaliaç...
# 54  [1 - Prope realizará expediente interno entre ...
# 55  [1 - VIII Prêmio de Fotografia encerra inscriç...
# 56  [1 - Reitoria prorroga horário de funcionament...
# 57  [1 - IsF abre inscrições para três cursos inte...
# 58  [1  - UFSJ oferece 14 vagas no Mestrado Profis...
# 59  [1 - Pesquisa de Autoavaliação Institucional e...
# 60  [1 - PPGeog  oferta disciplinas isoladas no pe...
# 61  [1 - UFSJ realiza concurso para professor subs...
# 62  [1 - Seaps informa prazo para comprovação de g...
# 63  [1 - Inverno Cultural recebe inscrições de pro...
# 64  [1 - Programas de`Pós-Graduação convidam para ...
# 65  [1 - Pós-Graduação em Enfermagem realiza aula ...
# 66  [1 - Período para indicação de bolsistas de in...
# 67  [1 -  Missa de Sétimo Dia de Carmen Maria da S...
# 68  [1 - Ascom informa procedimentos para aquisiçã...
# 69  [1 - Nead abre editais para tutores e orientad...
# 70  [1 - Ambulatório de Cantoterapia está com insc...
# 71  [1 - Instabilidades na internet dos campi Dom ...
# 72  [1 - Ntinf esclare sobre instabilidades na int...
# 73  [1 - Pós-Graduação em Geografia convida para d...
# 74  [1 - Pedidos para instalação de divisórias bal...
# 75  [1 - Progp divulga chamada interna para estági...
# 76  [1 - Lançado edital para o Programa de Qualifi...
# 77  [1 - Corrida Unificada recebe inscrições a par...
# 78  [1 - Defesa de dissertação na Pós-Graduação em...
# 79  [1 - Atenção: Inscrições para chamada interna ...
# 80  [1 - Assin lança editais para mobilidade acadê...
# 81  [1 - Reitoria da UFSJ lança projeto em Ouro Br...
# 82  [1 - Suspensão de fornecimento de energia no C...
#
#                                                  news numero        data
# 0   [O Conselho de Ensino, Pesquisa e Extensão (Co...      9   2018-10-9
# 1   [ A Divisão de Prefeitura (Dipre) informa aos ...     12  2018-10-15
# 2   [Boletim nº 10 - 10 de outubro de 20181 - Prog...     10  2018-10-10
# 3   [Boletim nº 11 - 11 de outubro de 20181 - Prog...     11  2018-10-11
# 4   [Boletim nº 14 - 17 de outubro de 20181- FAUF ...     14  2018-10-17
# 5   [A Fundação de Apoio à Universidade Federal de...     16  2018-10-19
# 6   [ A Comissão de Acessibilidade da Universidade...     15  2018-10-18
# 7   [ O projeto Comunica Extensão é o canal de div...     13  2018-10-16
# 8   [8 -, A Divisão de Administração de Pessoal in...     19  2018-10-24
# 9   [ A Pró-Reitoria de Gestão e Desenvolvimento d...     17  2018-10-22
# 10  [Boletim nº 24 - 5 de novembro de 20181 - Espe...     24   2018-11-5
# 72  [ O Núcleo de Tecnologia da Informação (Ntinf/...     88  2019-02-28
# 73  [ O Programa de Pós-Graduação em Geografia (PP...     86  2019-02-26
# 74  [Boletim nº 87 - 27 de fevereiro de 20191 - Pe...     87  2019-02-27
# 75  [ A Pró-Reitoria de Gestão e Desenvolvimento d...     89   2019-03-1
# 76  [ A Pró-Reitoria de Gestão e Desenvolvimento d...     90   2019-03-8
# 77  [3) As inscrições para a Corrida Unificada com...     92  2019-03-13
# 78  [ O Programa de Pós-Graduação em Engenharia Me...     93  2019-03-14
# 79  [3) A Pró-Reitoria de Gestão e Desenvolvimento...     91  2019-03-12
# 80  [ A Assessoria para Assuntos Internacionais da...     95  2019-03-18
# 81  [Iniciativa levará a administração da universi...     94  2019-03-15
# 82  [ A Divisão de Prefeitura de Campus (Dipre) in...     96  2019-03-19
#
# [83 rows x 5 columns]

# %% [markdown]
# # Insert Values into DB
# ## Insert "Boletims"

# %%
insert_boletim(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-329def40d86a> in <module>
# ----> 1 insert_boletim(df)
#
# <ipython-input-2-c0eed4ee1b1a> in insert_boletim(df)
#      61     for k, v in enumerate(df['news']):
#      62         sqlcommand = 'INSERT INTO  doug_server_app_boletim (data_boletim, numero) VALUES ("{}", {});'.format(df['data'][k], int(df['numero'][k]))
# ---> 63         cursor.execute(sqlcommand)
#      64     con.commit()
#      65     con.close()
#
# ~/anaconda3/lib/python3.7/site-packages/MySQLdb/cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# ~/anaconda3/lib/python3.7/site-packages/MySQLdb/cursors.py in _query(self, q)
#     310         db = self._get_db()
#     311         self._result = None
# --> 312         db.query(q)
#     313         self._do_get_result(db)
#     314         self._post_get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/MySQLdb/connections.py in query(self, query)
#     222         if isinstance(query, bytearray):
#     223             query = bytes(query)
# --> 224         _mysql.connection.query(self, query)
#     225
#     226     def _bytes_literal(self, bs):
#
# OperationalError: (1054, "Unknown column 'data_boletim' in 'field list'")

# %%
drop = 0
for i, news in enumerate(df.news):
    for j, new in enumerate(news):
        ##find id from boletim
        con = MySQLdb.connect('localhost', 'juaumpc', 'root')
        con.select_db('doug_db')
        con.set_character_set('utf8')

        cursor = con.cursor()
        print(i)
        cursor.execute('SELECT * from doug_server_app_boletim WHERE numero="{}" '.format(df['numero'][i]))
        instance = cursor.fetchone()
        data_upload = datetime.datetime.now().strftime("%Y-%m-%d")
        disponivel_em = 'https://ufsj.edu.br/ascom/boletim0{}.php'.format(df.numero[k])
        titulo = df['noticia-titulo'][i][j]
        corpo = new
        user_id = None
        boletim_fk_id = instance[0]
        print(titulo)
        sqlInsertString = "INSERT into doug_server_app_noticia(data_upload, disponivel_em, corpo, user_id, boletim_fk_id, titulo) VALUES('{}', '{}', '{}', {}, {}, '{}')".format(
                            data_upload, disponivel_em, corpo, 'NULL', boletim_fk_id, titulo)
        try:
            cursor.execute(sqlInsertString)
        except:
            df.drop(df.index[i])
            drop += 1
        con.commit()
        con.close()

# %%
df.loc['data': '1997']

# %%
df.news[77][0]

# %%
df['noticia-titulo'][3]
